# %% [markdown]
# # Get titles of the news from Varzesh3

# %%
from bs4 import BeautifulSoup
import requests
import csv
import re

# %%
def clean_text(text):
    
    return re.sub(r'\n\s*\n', '\n\n', text).strip()

# %%
def get_data(url, re_encode=False):
    
    r = requests.get(url)
    if re_encode:
        r.encoding = r.apparent_encoding                                
    if r.status_code != 200:
        raise Exception("Http Error: {}".format(r.status_code))
    else:
        return BeautifulSoup(r.text, 'lxml')

# %%
soup = get_data("http://www.varzesh3.com")

tabs = soup.findAll('div' , class_ ='tab-pane' , id = 'mostRecentNews')

# list of the links of all recent soccer realted news
urls = []
for item in tabs[1].findAll('a') :
    urls.append(f"http://varzesh3.com/{'/'.join(item['href'].split('/')[1:3])}")

# %%
with open('varzesh3.csv' , 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['title' , 'lead' , 'content'])

# %%
n = 0
for url in urls:     #only try the first two lines for now
    soup = get_data(url, re_encode=True)

    
    try:
        title = clean_text(soup.find('h1' , class_ = 'news-page--news-title').text)
        lead = clean_text(soup.find('p' , class_ = 'news-page--news-lead text-justify').text)
        content = clean_text(soup.find('div' , class_ = 'col-xs-12 news-page--news-text text-justify').text)
        with open('test.txt' ,encoding = "utf_8" ,  mode = 'a') as f:
            f.write(title)
            f.write(lead)
            f.write(content)
        with open('varzesh3.csv' , 'a') as csv_file:
            csv_writer = csv.writer(csv_file)
            csv_writer.writerow([title, lead, content])  
        print(f'This is news number {n}. \n')
        print(f"title:\n {title}'\nlead:\n{lead}\ncontent:\n{content}\n")
        n += 1
    except:
        print('no text!')
    print("-"*100)
# Out:
# This is news number 0.
#
# title:
#  ستاره بارسلونا؛ گزینه جدید یورگن کلوپ'
# lead:
# عثمان دمبله، وینگر فرانسوی بارسلونا مورد توجه لیورپول قرار گرفته است.
# content:
# به گزارش "ورزش سه"، لیورپول قصد دارد در فصل تابستان امسال خط حمله تیمش را تقویت کند و نام های زیادی در این خصوص مطرح شده است. گزینه مورد علاقه یورگن کلوپ را باید تیمو ورنر، مهاجم آلمانی و گلزن لایپزیش دانست، اما باشگاه آلمانی 53 میلیون پوند برای فروش ورنر تقاضا کرده و لیورپول فعلا از جذب او منصرف شده است.
#
# اما نشریه موندو دیپورتیوو مدعی شد در صورت عدم موفقیت در جذب تیمو ورنر، مرسی سایدی ها برای خرید عثمان دمبله اقدام خواهند کرد. دمبله در این سه فصل حضور در بارسلونا نمایش چندان موفقی نداشته و بازی های زیادی را به علت مصدومیت های مختلف از دست داده است.
#
# مشکلات مالی اخیر باعث شده بارسلونا مشکلی برای فروش عثمان دمبله نداشته باشد و حتی اخباری مبنی بر پذیرش پیشنهادی 40 میلیون یورویی برای انتقال ستاره فرانسوی از سوی بارسا نیز شنیده شده است. بارسلونا به دنبال جذب یک گزینه جدید در بخش هجومی است و نام ستاره هایی چون لائوتارو مارتینز یا نیمار در این خصوص مطرح شده است. در صورت ورود یک بازیکن جدید، شرایط برای عثمان دمبله در مسیر قرار گرفتن در ترکیب ثابت بلوگرانا دشوارتر از قبل خواهد شد و ممکن است آنها با لیورپول برای فروش این ستاره جوان به توافق دست یابند.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 1.
#
# title:
#  پیشنهاد جذاب PSG برای جذب ستاره لاتزیو'
# lead:
# به نظر می‌رسد که پاری سن ژرمن ۶۰ میلیون یورو برای جذب سرگی میلینکوویچ ساویچ از پاری سن ژرمن اقدام خواهد کرد.
# content:
# به گزارش "ورزش سه"، حالا حدود ۵ سال از حضور هافبک صربستانی یعنی سرگی میلینکوویچ ساویچ در سری آ و باشگاه لاتزیو می گذارد. این هافبک ۲۵ ساله طی فصول گذشته یکی از بهترین بازیکنان لاتزیو بوده و همواره نمایش های درخشانی ارائه داده است.
#
#  میلینکوویچ ساویچ در فصل جاری رقابت‌های سری آ نیز یکی از بهترین بازیکنان تیم اینزاگی بوده و در ۲۵ بازی برای این تیم آمار ۴ گل و ۴ پاس گل را به ثبت رسانده است. این هافبک صربستانی طی یکی دو فصل اخیر مورد توجه تیم‌های بزرگ مثل رئال مادرید و یوونتوس قرار گرفته اما نهایتا در لاتزیو ماندگار شده است.
#
# اگرچه هافبک ۲۷ ساله لاتزیو تا سال ۲۰۲۴ با این تیم قرارداد دارد اما با این حال گفته می‌شود که پاری سن ژرمن به شدت شرایط جذب این بازیکن را دنبال می‌کند. حالا و در همین رابطه le10sport مدعی شده که باشگاه فرانسوی قصد دارد برای تقویت خط هافبک خود ساویچ را به خدمت بگیرد و در این راستا نیز می خواهد یک پیشنهاد جذاب و ۶۰ میلیون یورویی به لاتزیو را ارائه دهد.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 2.
#
# title:
#  مقصد پیرلوی جدید ایتالیا مشخص شد'
# lead:
# به نظر می رسد اینتر مقصد بعدی ساندرو تونالی، ستاره جوان برشا خواهد بود.
# content:
# به گزارش "ورزش سه"، تونالی در فصل جاری عملکرد فوق العاده ای در ترکیب برشا ارائه داده است و به همین دلیل او را آندره پیرلوی جدید فوتبال ایتالیا لقب داده اند. همین عملکرد باعث ابراز علاقه تیم هایی چون بارسلونا، یونایتد و یوونتوس به خرید این ستاره 20 ساله شده، اما گاتزتا دلااسپورت مدعی شد اینتر از بالاترین شانس برای خرید او برخوردار است.
#
# مذاکرات بین اینتر و برشا برای انتقال ساندرو تونالی آغاز شده و اگرچه تا پیش از شیوع ویروس کرونا برشا حدود 50 میلیون یورو برای فروس تونالی درخواست کرده بود، اما حالا و با مشکلات مالی فعلی احتمال حاضر به تخفیف دادن و فروش او با 40 میلیون نیز می شود. تونالی در 23 بازی خود در سری آ در این فصل 5 پاس گل ارسال کرده و یک گل نیز به ثمر رسانده است.
#
# اینتز قصد دارد یک خط میانی ایتالیایی برای فصل بعد تشکیل دهد و تونالی می تواند در کنار بازیکنان جوانی چون نیکو بارلا و استفانو سنسی به میدان برود. پپ ماروتا، مدیر ورزشی اینتر رابطه خوبی با سران برشا دارد و اگر اتفاق خاصی رخ ندهد، تونالی در بازار نقل و انتقالات تابستانی راهی اینتر خواهد شد. این بازیکن احتمالا دستمزدی معادل سالانه 2.5 میلیون یورو در تیم جدیدش دریافت خواهد کرد.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 3.
#
# title:
#  تمرین گل گهر با حضور منشا و دیگران(عکس)'
# lead:
# تیم فوتبال گل گهر امروز عصر در زمین کمپ الیاف اولین تمرین گروهی اش را با حضور تمامی نفراتش برگزار کرد.
# content:
# به گزارش" ورزش سه" امروز گل گهر با حضور تمامی بازیکنانش تمرین کرد. این تیم که هفته گذشته پس از اینکه گفته می شد چند بازیکنش مشکوک به ویروس کرونا هستند ، یک هفته تمریناتش را تعطیل کرد اما بعد از انجام دو تست دیگر و صدور مجوز از سوی فدراسیون پزشکی ورزشی این تیم با تمامی نفراتش تمرین کرد.
#
# در این تمرین بازیکنانی مثل گادوین منشا ، سیداحمد موسوی و مهرداد عبدی به تمرین اضافه شده بودند. در این تمرین البته دیگر بازیکنان بازیکنان مثل تمرین روز گذشته روز با نشاط و با روحیه ای را سپری کردند. بازیکنان گل گهر از جمله مهرداد بایرامی ، علیرضا ابراهیمی، بهنام برزای، یونس شاکری، احمدزنده روح،میلاد فراهانی و ...امروز زیر نظر مجید جلالی دور جدید تمرینات برای برگزاری بازی های باقیمانده لیگ برتر انجام دادند.
#
# از نکات جالت تمرین گل گهر این است که برخی از بازیکنان حسابی در رنگ پوستشان برنزه شده و از از نظر بدنی هم فرم خوبی دارند. مهرداد بایرامی، گادوین منشا ، ابراهیمی و موسوی لااقل از نظر رنگ پوست متفاوت تر از دیگران هستند. البته که مجید جلالی هم اینروزها مرد اول تمرینات تیمش است و او هم از فرم و آمادگی بالایی برخوردار است به طوری که به نظر می رسد در روزهای قرنطینه تمرینات اختصاصی و جدی را پا به پای بازیکنانش انجام داده است.
#
# او با گل گهر یک ماموریت ویژه دارد و آن ماندن برای یک فص دیگر در رقابت های لیگ برتر است. اتفاقی که تا الان افتاده و باید 9 هفته دیگر تداوم داشته باشد. هرچند دو پیروزی مهم برای صنعت نفت و استقلال و همچنین تساوی دقیقه آخری برابر تراکتور و کسب هفت امتیاز از تیم های بالانشین حالا به جلالی و شاگردانش این اعتماد به نفس و انگیزه را هم داده که بتوانند به رتبه های بهتری در جدول فکر کنند.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 4.
#
# title:
#  سعادتمند به نکونام: ما هم ۲ خارجی داریم!'
# lead:
# مدیرعامل باشگاه استقلال به صحبت‌های سرمربی فولاد درباره احتمال عدم حضور در دیدار معوقه دو تیم واکنش نشان داد.
# content:
# به گزارش "ورزش سه"، ساعاتی قبل جواد نکونام اعلام کرد باید آیاندا پاتوسی به ایران برگردد و بعد دیدار فولاد خوزستان مقابل استقلال برگزار شود و سازمان لیگ باید دیدار دو تیم را به تعویق بیاندازد.
#
# احمد سعادتمند، مدیرعامل باشگاه استقلال درباره درخواست رسمی سعید آذری، مدیرعامل باشگاه فولاد برای تعویق دیدار با استقلال اظهار کرد: نه اطلاعی درباره نامه‌ی آقای سعید آذری، دوست خوبم به سازمان لیگ دارم و نه صحبت‌های آقای نکونام عزیز که استقلالی هم هست را شنیده‌ام.
#
# او درباره اینکه نکونام عنوان کرده تا زمان نیامدن پاتوسی به ایران نباید بازی با استقلال برگزار شود، ابراز کرد: ما هم دو بازیکن خارجی داشتیم و هر دو نفر مطالبات زیادی را از گذشته داشتند ولی ما تلاش کردیم و حداقل ۲۰ روز قبل از مسابقات، این عزیزان به جمع ما اضافه شدند. آقای دیاباته از فردا به جمع تیم اضافه می‌شود. البته نباید این موضوعات مطرح شود.
#
# مدیرعامل باشگاه استقلال تصریح کرد: من هم مثل سایر مدیران عامل باشگاه‌های لیگ برتری معتقد هستم که باید تمام مدیران، کادر فنی و سرمربیان تیم‌ها از سوی سازمان لیگ دعوت می‌شدند و در یک جلسه، تمام نظرات برای آغاز، نحوه و زمان برگزاری شنیده می‌شد.
#
# او اضافه کرد: الان برخی از باشگاه‌ها نمی‌توانند پروتکل‌ها را رعایت کنند و به همین دلیل باید در یک جلسه و طی یک خرد جمعی، تصمیم بهتری گرفته می‌شد تا کار را بهتر جلو ببرند.
#
# مدیرعامل باشگاه استقلال درباره اینکه برخی باشگاه‌ها تصمیم به انصراف از لیگ برتر در صورت برگزاری بازی‌ها گرفته‌اند، گفت: می‌بینیم که لیگ ایتالیا هم در حال شروع است.  ما نیز اعتقاد داریم که قهرمان باید در زمین مسابقه مشخص شود. ما یک بازی عقب افتاده داریم و حداکثر امتیازی که می‌توانیم در این فصل به دست آوریم، ۳۰ امتیاز است. به همین خاطر شانس قهرمانی را برای خودمان قائل هستیم.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 5.
#
# title:
#  ستاره بارسلونا در مسیر یک رکورد تاریخی'
# lead:
# آرتورو ویدال، هافبک 32 ساله بارسلونا در مسیر یک رکورد فوق العاده در عرصه باشگاهی قرار دارد.
# content:
# به گزارش "ورزش سه، آرتورو ویدال تنها بازیکنی است که با سه باشگاه مختلف و همچنین در لیگ های بزرگ اروپا به این مهم دست یافته است. این روند در فصل 12-2011 و در دوران حضور ویدال در یوونتوس آغاز شد و تا امروز ادامه دارد. ستاره شیلیایی می تواند این فصل و در لباس بارسلونا برای نهمین بار متوالی عنوان قهرمانی لیگ را فتح کند. سه قهرمانی در یوونتوس، سه جام در بایرن مونیخ و دو لالیگا با لباس بارسلونا، کارنامه خیره کننده ویدال در سال های اخیر بوده است.
#
# آرتورو ویدال در این رابطه گفت: "فتح 9 قهرمانی لیگ پیاپی رویایی خواهد بود، زیرا دستیابی به این رکورد بسیار دشوار است. من هنوز احساس خوبی دارم و به مبارزه و برنده شدن در جام های مختلف ادامه خواهم داد. معدود بازیکنانی در تاریخ فوتبال این کار را انجام داده اند و من به این روند افتخار می کنم. امیدوارم این فصل در لباس بارسلونا برای نهمین فصل متوالی موفق به قهرمانی در لیگ شوم."
#
# علیرغم شایعات فراوان در مورد جدایی آرتورو ویدال، نشریه موندو دیپورتیوو دیروز مدعی شد این بازیکن به مدیران تیمش اطلاع داده خواهان ماندن در نوکمپ است و می خواهد با لباس بارسا فاتح لیگ قهرمانان هم بشود. جالب اینجاست علیرغم این کارنامه فوق العاده در لیگ، آرتورو ویدال هنوز در لباس هیچ تیمی موفق به کسب عنوان قهرمانی در لیگ قهرمانان نشده است.
#
# ----------------------------------------------------------------------------------------------------
# no text!
# ----------------------------------------------------------------------------------------------------
# This is news number 6.
#
# title:
#  رونالدو و رئال مادرید تاثیر متقابلی داشتند'
# lead:
# لوییس فیگو، اسطوره فوتبال پرتغال به تمجید از کریستیانو رونالدو پرداخت.
# content:
# به گزارش "ورزش سه"، تا پیش از ظهور رونالدو، بسیاری رقابت بهترین بازیکن تاریخ پرتغال را بین لوییس فیگو و اوزه بیو می دانستند، اما رونالدو همه معادلات را بهم زد و پرافتخارترین بازیکن تاریخ این کشور لقب گرفت. لوییس فیگو نیز مدعی شد هر تیمی علاقمند به داشتن بازیکنی مانند رونالدو است. او همچنین معتقد است رئال مادرید و رونالدو هر دو به پیشرفت یکدیگر کمک کرده اند.
#
# لوییس فیگو گفت: "رونالدو رئال مادرید را به بزرگترین باشگاه  جهان تبدیل کرد و البته رئال مادرید باعث شد رونالدو بزرگترین بازیکن دنیا شود. هر باشگاهی می خواهد بازیکنی مانند رونالدو را در تیم خود ببیند. او بازیکنی است که عملکرد باثباتی دارد و در یک فصل تعداد گل هایی فراوان و باورنکردنی را به ثمر می رساند. وجود رونالدو باعث می شود گل های پرتعدادی در یک فصل برای هر تیمی تضمین ضشود و این مهم ترین مسئله در دنیای فوتبال است.
#
# در گذشته رقابت برای کسب توپ طلا خیلی دشوارتر بود، زیرا رقیبان زیادی برای کسب این عنوان وجود داشتند. اما طی این سال ها فقط کریستیانو رونالدو و لیونل مسی در کنار هم برای بردن این جایزه رقابت کرده اند."
#
# ----------------------------------------------------------------------------------------------------
# This is news number 7.
#
# title:
#  سانتیاگو برنابئو برای فصل بعد آماده می شود(عکس)'
# lead:
# اخیراً مسئولان باشگاه رئال مادرید روند بازسازی ورزشگاه خانگی خود یعنی سانتیاگوبرنابئو را آغاز کرده‌اند.
# content:
# به گزارش "ورزش سه"، دو ماه پیش و بعد از شیوع گسترده ویروس کرونا در قاره اروپا و البته کشور اسپانیا، رقابت‌های لالیگا به حالت تعلیق در آمد. با این حال طی روزهای گذشته مشخص شد مسابقات لالیگا از ماه ژوئن پیگیری خواهد شد و تیم‌ها ادامه بازی‌های خود را پشت درهای بسته و در ورزشگاه های خالی از تماشاگر برگزار خواهند کرد.
#
# رئال مادرید از وقفه به وجود آمده در مسابقات استفاده کرد و در این مدت برای بازسازی ورزشگاه خانگی خود یعنی سانتیاگوبرنابئو اقدام کرد؛ کاری که پیش از این هم مسئولان رئال به دنبال یافتن فرصتی برای انجام آن بودند.
#
# ادامه بازی های خانگی رئال مادرید در فصل جاری اما در ورزشگاه دی استفانو برگزار خواهد شد؛ موضوعی که به مسئولان لوس بلانکوس اجازه می‌دهد تا فرصت کافی را برای بازسازی کامل برنابئو در اختیار داشته باشند.
#
# از طرف دیگر برنامه این است که از ماه سپتامبر تا نوامبر، حداکثر 30 درصد ظرفیت ورزشگاه ها پر شود و سپس از نوامبر تا ژانویه نیز نیمی از ظرفیت ورزشگاه ها به هواداران اختصاص داده شود. برنامه نهایی این است که از ژانویه 2021 نیز حضور هواداران بدون محدودیت باشد. این در حالیست که تا آن زمان سانتیاگوبرنابئو آماده پذیرایی از بازی های خانگی رئال مادرید خواهد بود.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 8.
#
# title:
#  واکنش تند ماریو بالوتلی به یک اتهام عجیب'
# lead:
# ماریو بالوتلی مهاجم ایتالیایی برشا به شایعات عدم حضورش در تمرینات این تیم واکنش نشان داد.
# content:
# به گزارش "ورزش سه"، اخیراً صحبت‌هایی در رابطه با عدم حضور ماریو بالوتلی در تمرینات تیم برشا مطرح شد. در همین رابطه نیز امروز اسکای اسپورتس ایتالیا دوباره خبری را مبنی بر غیبت مجدد ماریو بالوتلی در تمرینات برشا کار کرد؛ این منبع همچنین اعلام کرد که این موضوع می‌تواند باعث فسخ قرارداد بالوتلی با باشگاه ایتالیایی شود.
#
# بالوتلی حالا به این موضوع واکنش تندی نشان داده است. او در اینستاگرام خود در این باره اذعان کرد: " چطور می‌توانید بنویسید که من در زمین تمرین حاضر نبودم؟ در همه جلسات تمرینی خبرنگاران و دوربین های تلویزیونی حضور دارند."
#
# بالوتلی در ادامه عنوان کرد: " من تقریباً در تمام جلسات تمرینی حضور دارم! چگونه می توانید شواهد را انکار کنید؟ فکر نمی‌کردم که من مانند یک فانتوم باشم که برای دوربین ها نامرئی باشم. در زمان مناسب من همه چیز را توضیح خواهم داد و شما نیز متوجه کل اتفاقات خواهید شد."
#
# ----------------------------------------------------------------------------------------------------
# This is news number 9.
#
# title:
#  کلافگی مورینیو؛ حالا نوبت ما فوتبالی هاست!'
# lead:
# به نظر می رسد ژوزه مورینیو از عدم برگزاری مسابقات لیگ برتر کلافه شده است.
# content:
# به گزارش "ورزش سه"، تعطیلی موقعت در سه ماه اخیر باعث لغو مسابقات فوتبال در تمام نقاط دنیا شد و حالا این روند کم کم در حال به پایان رسیدن است. ژوزه مورینیو نیز مدعی شد مردم منتظر آغاز رقابت های فوتبال هستند و وظیفه فوتبالی ها براورده کردن این انتظار است.
#
# ژوزه مورینیو گفت: "ما نباید خودخواه باشیم و بیش از حد مطالبه کنیم. حال نوبت از خودگذشتی ماست. به عنوان مثال وقتی بازیکنان در رقابت های یورو و جام جهانی بازی می کنند به سختی تعطیلات دارند و آنها از تعطیلات مستقیم به تمرینات می آیند و بعضی اوقات کمتر از یک هفته برای بازی در اولین مسابقه لیگ برتر تمرین می کنند.
#
# در این مقطع مردم نگران تلاش برای دستیابی به آنچه هرگز نداشته اند هستند. به عنوان مثال ما در مورد آسیب دیدگی های قبل از فصل صحبت می کنیم، اما صدمات قبل از فصل وجود دارد. در فصول عادی نیز آسیب دیدگی های قبل از فصل رخ می دهند، بنابراین ما نمی توانیم انتظار داشته باشیم این بار چنین اتفاقی تکرار نشود.
#
# ما نمی توانیم بیشتر از آنچه مسئولان برایمان مهیا می کنند درخواست کنیم، این نهایت امنیت است و فکر می کنم اکنون زمان آن رسیده که فقط بازی کنیم و آنچه مردم می خواهند را برایشان فراهم کنیم. شما به کشورهای دیگر نظیر آلمان نگاه کنید و آنها پیش از این بازی ها را آغاز کرده اند، فوتبال این هفته در پرتغال و هفته آینده در اسپانیا شروع می شود. ما فوتبالی بودیم که هرگز متوقف نمی شد، حتی در دوره هایی مانند کریسمس. ما لیگ جهانی هستیم و بازی نکردن احساس عجیبی می دهد، اما ما با صبر و شکیبایی منتظر هستیم تا چراغ سبز آغاز بازی ها روشن شود."
#
# ----------------------------------------------------------------------------------------------------
# This is news number 10.
#
# title:
#  علوی: برانکو بهترین‌ها را انتخاب می‌کرد'
# lead:
# بازیکن سابق تیم ملی فوتبال ایران پیرامون شائبه‌هایی که درباره دعوت شدن‌اش از سوی برانکو وجود داشت، توضیحاتی ارائه داد.
# content:
# به گزارش "ورزش سه"، چندی پیش علیرضا واحدی نیکبخت در مصاحبه‌ای عنوان کرد بازیکنان خوزستانی در زمان سرمربیگری برانکو ایوانکوویچ در تیم ملی، باند تشکیل داده بودند که حالا یکی از ملی پوشان آن زمان، به این مسئله واکنش نشان داده است.
#
# سید محمد علوی، مدیر فعلی تیم فولاد خوزستان، در مورد دعوت شدن‌اش به تیم ملی در زمان سرمربیگری برانکو و اینکه برخی می‌گویند دعوت او و چند بازیکن دیگر به تیم ملی حق این نفرات نبوده است، ابراز کرد: این موضوع را کاملا رد می‌کنم چون برانکو بهترین بازیکنان را انتخاب می‌کرد.
#
# او ادامه داد: زمان او بازیکنان بزرگی چون جواد نکونام، رحمان رضایی، علی دایی، مهرداد میناوند و علی کریمی حضور داشتند که همگی ما سعی می‌کردیم به تیم ملی دعوت ‌شویم.
#
# علوی یادآور شد: کارنامه برانکو مشخص است و هرکسی بخواهد آن را زیر سوال ببرد، برایش متاسف هستم. در زمان برانکو و کی‌روش ما کارهای بزرگی را انجام دادیم و کارنامه‌شان درخشان است. نباید با این مسائل حاشیه‌سازی کنیم.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 11.
#
# title:
#  فیفا پروتکل های بازگشت به فوتبال را تدوین کرد'
# lead:
# رییس کمیته پزشکی سازمان لیگ اعلام کرد فیفا پروتکل های بازگشت به فوتبال را تدوین کرده است.
# content:
# به گزارش "ورزش سه"، زهره هراتیان به سایت سازمان لیگ  گفت: فیفا پروتکل های بازگشت به فوتبال را با کمک  و همفکری  سازمان بهداشت جهانی به فدراسیون های عضو ابلاغ کرد.  این پروتکل ۱۹
#  صفحه ای تمامی تیم های حرفه ای ، آماتور و پایه را شامل می شود. تدوین این پروتکل براساس تحقیقات و مقالات تخصصی چاپ شده در حوزه ورزش، فوتبال و بیماری کوید ۱۹ است.
#
# وی افزود: با توجه به این پروتکل می توان گفت که فیفا به همکاری فدراسیون های عضو با وزارت بهداشت هر کشور تاکید و اعلام کرده قوانین وزارت بهداشت کشورها از اهمیت و احترام خاصی برخوردارند.
#
# هراتیان تصریح کرد: مرکز پزشکی سازمان لیگ فوتبال ایران( ایفمارک) در حال ترجمه سریع این پروتکل بهداشتی و تلفیق آن با دستورات  وزارت بهداشت کشورمان است تا این پروتکل به شکل کاربردی‌تر قابل اجرا شود. مشکلات تیم های حرفه ای، آماتور و رده های پایه در این پروتکل بهداشتی که از سوی فیفا تدوین شده  قابل حل است.
#
# ----------------------------------------------------------------------------------------------------
# no text!
# ----------------------------------------------------------------------------------------------------
# This is news number 12.
#
# title:
#  حسرت ابدی بارسلونا؛ ستاره ای که نصیب بایرن شد!'
# lead:
# آلفونسه دیویس، ستاره کانادایی بایرن فاصله ای تا انتقال به بارسلونا نداشته است.
# content:
# به گزارش "ورزش سه"، آلفونسه دیویس در ماه های اخیر بی تردید یکی از بهترین بازیکنان بایرن مونیخ بوده است و حالا نشریه موندو دیپورتیوو ادعا می کند که بارسلونا می توانست ستاره این روزهای بوندسلیگا را با قیمت فقط 8 میلیون یورو در سال 2017 جذب کند. بارسلونا زمانی که این بازیکن 17 ساله در سال 2017 در ونکوور مشغول به بازی کردن بود، پیشرفت او را زیر نظر داشت و استعدادیاب های این تیم حتی چند بار از نزدیک عملکرد آلفونسه دیویس را تماشا کرده بودند.
#
# دیویس اولین بازی رسمی اش را در جام طلایی کونکاکاف در ژوئن سال 2017 در ترکیب تیم ملی کانادا انجام داد و این بازیکن جوان در چهار بازی سه گل به ثمر رساند. علیرغم توافق برای انتقال هشت میلیون یورویی با مدیر برنامه آلفونسه دیویس، در نهایت بارسلونا منصرف شد و این انتقال بهم خورد.
#
# در نهایت دیویس در ژانویه 2019 و با مبلغ 10 میلیون یورو به بایرن مونیخ پیوست. 17 ماه پس از این انتقال، حالا این بازیکن 19 ساله در حدود 45 میلیون یورو ارزشگذاری شده و یکی از بهترین بازیکنان بایرن مونیخ به شمار می آید. دیویس بازیکنی همه کاره است که می تواند به عنوان مدافع چپ، وینگر چپ و حتی راست بازی کند. دیویس در 33 بازی در این فصل سه گل به ثمر رسانده و هشت پاس گل نیز ارسال کرده است.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 13.
#
# title:
#  احتمال انجام یک معاوضه بین یووه و اتلتیکومادرید'
# lead:
# گفته می‌شود این احتمال وجود دارد یوونتوس و اتلتیکو مادرید برای معاوضه داگلاس کاستا و توماس پارتی با یکدیگر مذاکره کنند.
# content:
# به گزارش "ورزش سه"، وینگر برزیلی یوونتوس در فصل جاری با مصدومیت های متوالی دست و پنجه نرم کرده است؛ موضوعی که باعث شد او اکثر بازی های این فصل یوونتوس را از دست بدهد و خارج از ترکیب تیم مائوریتزیو ساری باشد.
#
# از طرفی اخیراً توتو اسپورت پیشنهاد کرده بود که یوونتوس برای موفقیت در جذب پل پوگبا، پای ستاره برزیلی خود یعنی داگلاس کاستا را با معامله انتقال این بازیکن به تورین باز کند.
#
# حالا و در همین رابطه اما کالچیو مرکاتو مدعی شده که سرمربی آرژانتینی اتلتیکو مادرید یعنی دیگو سیمئونه علاقه زیادی به سبک بازی داگلاس کاستا دارد و می خواهد این بازیکن را به وندا متروپولیتانو منتقل کند.
#
# از طرف دیگر چند بازیکن اتلتیکو مادرید مورد توجه باشگاه یوونتوس قرار دارند که یکی از مهم ترین آنها هافبک غنایی روخی بلانکو یعنی توماس پارتی است. این در حالی است که پارتی یکی از ارکان تیم سیمئونه به حساب می‌آید و بعید به نظر می‌رسد سرمربی آرژانتینی راضی به جدایی او شود.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 14.
#
# title:
#  استراحت مجیدی به فرشید اسماعیلی'
# lead:
# هافبک شماره ٨ استقلال امروز در تمرین گروهی شرکت نکرد.
# content:
# به گزارش ''ورزش سه''، فرشید اسماعیلی بعد از پشت سر گذاشتن مصدومیت نسبتا طولانی با شروع تمرینات استقلال حضور فعالی در تمرین این تیم داشته است و از آماده ترین بازیکنان این تیم است.
#
# با این حال اسماعیلی به دلیل شرایط بدنی با تصمیم فرهاد مجیدی امروز به صورت اختصاصی تمرین کرد و در تمرین گروهی حضور نداشت.
#
# البته اسماعیلی مشکلی از بابت مصدومیت ندارد و از فردا در تمرین گروهی در کنار سایر بازیکنان تمرین خواهد کرد.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 15.
#
# title:
#  هنوز آماده انتقال به لیورپول نبودم'
# lead:
# کریستین کوفی، بازیکن جوان فرانسوی از دلایل رد پیشنهاد لیورپول سخن گفت.
# content:
# به گزارش "ورزش سه"، کریستین کوفی در تابستان سال 2018 و قبل از انتقال به سری آ مورد توجه لیورپول قرار گرفته بود، اما در نهایت این انتقال رخ نداد. حالا کریستین کوفی، وینگر فعلی فیورنتینا فاش کرد که چرا علیرغم تمایل شدید صدرنشین فعلی لیگ برتر، او شانس پیوستن به لیورپول را از موناکو در تابستان 2018 رد کرده است.
#
# کریستن کوفی گفت: "تقریبا در آخرین لحظه کمی تصمیم گرفته شد. من از علاقه لیورپول بسیار غافلگیر شدم، اما فیورنتینا را برای پیشرفت انتخاب کردم. لیورپول بیش از یک باشگاه بزرگ است و من در آن زمان و در سال 2018 آماده انتقال به این تیم نبودم.
#
# حضور در فیورنتینا فرصتی برای رشد در کنار بازیکن بزرگی مانند فرانک ریبری است و من می توانم چیزهای زیادی بیاموزم. او برای من مثل یک افسانه است، ما در فرانسه درباره ریبری صحبت کردیم. او کارهای بزرگ در فوتبال انجام داده است و به همین دلیل ما فقط می توانیم عملکرد ریبری را تحسین کنیم.
#
# ریبری الگوی من بود، اما رفتاری ساده و جالب دارد و او شخصیت خوبی برای بازیکنان جوان محسوب می شود. من دو سال فوق العاده در ترکیب تیم دوم فیورنتینا داشتم و برای آینده مهمترین موضوع داشتن یک پروژه ورزشی است. من می خواهم به طور مرتب با تیم اول تمرین کنم و می دانم که فصل بعد برای من مهم خواهد بود. من 100 درصد آماده هستم.
#
# ----------------------------------------------------------------------------------------------------
# This is news number 16.
#
# title:
#  خداحافظی کوتاه و تلخ اینتر با ستاره جنجالی! (عکس)'
# lead:
# بیانیه باشگاه اینتر در مورد مائورو ایکاردی مورد توجه کاربران شبکه های اجتماعی قرار گرفته است.
# content:
# به گزارش "ورزش سه"، امروز باشگاه پاری سن ژرمن اعلام کرد بعد از یک سال حضور قرضی مائورو ایکاردی در ترکیب این تیم، با او برای قرارداد دائم به توافق رسید و مائوریتو تا سال 2024 در پارک دوپرنس بازی خواهد کرد.
#
# هشتمین گلزن تاریخ باشگاه اینتر، یک سال قبل و بعد از جنجال های فراوان از این تیم جدا شد و علیرغم تمایل به ماندن، در نهایت مدیران اینتر او را به پاری سن ژرمن واگذار کردند. اما به نظر می رسد باشگاه اینتر هنوز هم دل خوشی از مائورو ایکاردی ندارد و امروز آنها با انتشار بیانیه ای کوتاه 47 کلمه ای و با لحنی نه چندان دوستانه، توافق با باشگاه فرانسوی برای انتقال مائوریتو را اعلام کردند. مائورو ایکاردی شش فصل برای اینتر به میدان رفت و موفق به زدن 124 گل و ارسال 39 گل برای این تیم شد.
#
# در این بیانیه آمده است: "باشگاه اینتر اعلام می کند انتقال مائورو ایکاردی به پاری سن ژرمن نهایی شده است. مهاجم متولد 1993، به طور دائم به باشگاه فرانسوی نقل مکان کرده است. این باشگاه از بازیکن به علت شش فصلی با ما سپری کرد تشکر کرده و برای او در دوران حرفه ای آینده اش آرزوی موفقیت می کند."
#
# ----------------------------------------------------------------------------------------------------
